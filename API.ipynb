# %% [markdown]
# ### API derived of top characters chosen of dataset's most popular game chosen. ###

# %%
import requests

import requests

url = "https://league-of-legends-galore.p.rapidapi.com/api/getChampTierList"

querystring = {"tier":"s+","region":"kr","rank":"master"}

headers = {
	"X-RapidAPI-Key": "fb496562e4mshb81269deda5cd9cp1563fejsn5efef0148fb9",
	"X-RapidAPI-Host": "league-of-legends-galore.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {
#   "sTier": [
#     {
#       "name": "Malphite",
#       "role": "MID",
#       "winRate": "65.9%"
#     },
#     {
#       "name": "Fiora",
#       "role": "TOP",
#       "winRate": "57.6%"
#     },
#     {
#       "name": "Elise",
#       "role": "JUNGLE",
#       "winRate": "57.0%"
#     },
#     {
#       "name": "Gragas",
#       "role": "JUNGLE",
#       "winRate": "56.5%"
#     },
#     {
#       "name": "Zoe",
#       "role": "MID",
#       "winRate": "56.4%"
#     },
#     {
#       "name": "Blitzcrank",
#       "role": "SUPPORT",
#       "winRate": "56.3%"
#     },
#     {
#       "name": "Talon",
#       "role": "MID",
#       "winRate": "56.3%"
#     },
#     {
#       "name": "Kennen",
#       "role": "TOP",
#       "winRate": "56.3%"
#     },
#     {
#       "name": "Rakan",
#       "role": "SUPPORT",
#       "winRate": "55.7%"
#     },
#     {
#       "name": "Zeri",
#       "role": "ADC",
#       "winRate": "54.6%"
#     },
#     {
#       "name": "Jax",
# ...
